# %%
import pandas as pd

# Đọc dữ liệu
euro12 = pd.read_csv("euro2012.csv")

# In euro12: type, shape, columns
print(type(euro12))
print(euro12.shape)
print(euro12.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (16, 7)
# Index(['Team', 'Goals', 'Shots on Target', 'Shots', 'Shooting Accuracy',
#        'Yellow Cards', 'Red Cards'],
#       dtype='object')

# %% [markdown]
# #1, in giá trị cột Goals

# %%
print(euro12["Goals"])
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# #2, số đội tham gia Eruo 2012 là:

# %%
print("Số đội:", euro12["Team"].nunique())
# Out:
# Số đội: 16

# %% [markdown]
# #3, in thông tin

# %%
print(euro12.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Team               16 non-null     object
#  1   Goals              16 non-null     int64
#  2   Shots on Target    16 non-null     int64
#  3   Shots              16 non-null     int64
#  4   Shooting Accuracy  16 non-null     object
#  5   Yellow Cards       16 non-null     int64
#  6   Red Cards          16 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 1.0+ KB
# None

# %% [markdown]
# #4, Tạo data frame discipline (Team, Yellow Cards, Red Cards)

# %%
discipline = euro12[["Team", "Yellow Cards", "Red Cards"]]
print(discipline)
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             4          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          0
# 10             Portugal             9          0
# 11  Republic of Ireland             6          0
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             4          0
# 15              Ukraine             5          0

# %% [markdown]
# #5. Sắp xếp discipline giảm dần theo Red Cards, Yellow Cards

# %%
discipline_sorted = discipline.sort_values(
    by=["Red Cards", "Yellow Cards"], 
    ascending=False
)
print(discipline_sorted)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 7                 Italy            16          0
# 13                Spain            11          0
# 10             Portugal             9          0
# 1        Czech Republic             7          0
# 9                Poland             7          0
# 4                France             6          0
# 11  Republic of Ireland             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 0               Croatia             4          0
# 2               Denmark             4          0
# 5               Germany             4          0
# 14               Sweden             4          0

# %% [markdown]
# #6a. Tính trung bình Yellow Card

# %%
print("Trung bình Yellow Cards:", euro12["Yellow Cards"].mean())
# Out:
# Trung bình Yellow Cards: 6.75

# %% [markdown]
# #6b. Lọc các đội ghi hơn 6 bàn thắng

# %%
print(euro12[euro12["Goals"] > 6])
# Out:
#        Team  Goals  Shots on Target  Shots Shooting Accuracy  Yellow Cards  \
# 5   Germany     10               32     80               40%             4
# 13    Spain     12               42    100               42%            11
#
#     Red Cards
# 5           0
# 13          0

# %% [markdown]
# #7. In các đội bắt đầu bằng chữ 'G'

# %%
print(euro12[euro12["Team"].str.startswith("G")])
# Out:
#       Team  Goals  Shots on Target  Shots Shooting Accuracy  Yellow Cards  \
# 5  Germany     10               32     80               40%             4
# 6   Greece      5                7     22               32%             9
#
#    Red Cards
# 5          0
# 6          1

# %% [markdown]
# #8. In 7 cột đầu của euro12

# %%
print(euro12.iloc[:, :7])
# Out:
#                    Team  Goals  Shots on Target  Shots Shooting Accuracy  \
# 0               Croatia      4               13     32               40%
# 1        Czech Republic      4                9     26               35%
# 2               Denmark      4               10     27               37%
# 3               England      5               11     40               28%
# 4                France      3               22     65               34%
# 5               Germany     10               32     80               40%
# 6                Greece      5                7     22               32%
# 7                 Italy      6               20     63               31%
# 8           Netherlands      2               12     60               20%
# 9                Poland      2               11     29               38%
# 10             Portugal      6               22     74               30%
# 11  Republic of Ireland      1                7     29               24%
# ...

# %% [markdown]
# #9. In tất cả các cột, trừ 3 cột

# %%
print(euro12.iloc[:, :-3])
# Out:
#                    Team  Goals  Shots on Target  Shots
# 0               Croatia      4               13     32
# 1        Czech Republic      4                9     26
# 2               Denmark      4               10     27
# 3               England      5               11     40
# 4                France      3               22     65
# 5               Germany     10               32     80
# 6                Greece      5                7     22
# 7                 Italy      6               20     63
# 8           Netherlands      2               12     60
# 9                Poland      2               11     29
# 10             Portugal      6               22     74
# 11  Republic of Ireland      1                7     29
# 12               Russia      5               15     58
# 13                Spain     12               42    100
# 14               Sweden      5               12     51
# 15              Ukraine      2               13     28

# %% [markdown]
# #10. In các cột Team, Goals, Shooting Accuracy, Yellow Cards, Red Cards

# %%
print(euro12[["Team", "Goals", "Shooting Accuracy", "Yellow Cards", "Red Cards"]])
# Out:
#                    Team  Goals Shooting Accuracy  Yellow Cards  Red Cards
# 0               Croatia      4               40%             4          0
# 1        Czech Republic      4               35%             7          0
# 2               Denmark      4               37%             4          0
# 3               England      5               28%             5          0
# 4                France      3               34%             6          0
# 5               Germany     10               40%             4          0
# 6                Greece      5               32%             9          1
# 7                 Italy      6               31%            16          0
# 8           Netherlands      2               20%             5          0
# 9                Poland      2               38%             7          0
# 10             Portugal      6               30%             9          0
# 11  Republic of Ireland      1               24%             6          0
# ...

# %% [markdown]
# #11. In các cột 'Team', 'Shooting Accuracy' cho England, Italy, Russia

# %%
print(euro12[euro12["Team"].isin(["England", "Italy", "Russia"])]
      [["Team", "Shooting Accuracy"]])
# Out:
#        Team Shooting Accuracy
# 3   England               28%
# 7     Italy               31%
# 12   Russia               26%
