# %%
class SinhVien:
    def __init__(self, ma_sv, ho_ten, lop):
        self.ma_sv = ma_sv
        self.ho_ten = ho_ten
        self.lop = lop

    def info(self):   # dùng phương thức info để in thông tin sv
        print(f"Mã sinh viên: {self.ma_sv}, Tên sinh viên: {self.ho_ten}, Lớp: {self.lop}")
