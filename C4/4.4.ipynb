# %%
import pandas as pd

# %% [markdown]
# # Input

# %%
ser1 = pd.Series([1, 2, 3, 4, 5])
ser2 = pd.Series([4, 5, 6, 7, 8])

# %% [markdown]
# # 1. Xóa các mục của ser1 có mặt trong ser2

# %%
ser1_diff = ser1[~ser1.isin(ser2)]
print("Ser1 sau khi xóa các mục có mặt trong ser2:")
print(ser1_diff)
# Out:
# Ser1 sau khi xóa các mục có mặt trong ser2:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# # 2. Lấy tất cả các mục của ser1 và ser2 nhưng không nằm chung trong cả hai (symmetric difference)

# %%
symmetric_diff = pd.concat([ser1, ser2]).drop_duplicates(keep=False)
print("\nCác mục không nằm chung trong cả hai Series:")
print(symmetric_diff)
# Out:
# Các mục không nằm chung trong cả hai Series:
# 0    1
# 1    2
# 2    3
# 2    6
# 3    7
# 4    8
# dtype: int64
