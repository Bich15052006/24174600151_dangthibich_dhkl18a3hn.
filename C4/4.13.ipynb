# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Input

# %%
ser1 = pd.Series([10, 9, 6, 5, 3, 1, 12, 8, 13])
ser2 = pd.Series([1, 3, 10, 13])

# %% [markdown]
# # 1. Xếp chồng theo chiều ngang (horizontal)

# %%
df_horizontal = pd.concat([ser1.reset_index(drop=True), ser2.reindex(ser1.index)], axis=1)
df_horizontal.columns = ['ser1', 'ser2']
print("DataFrame xếp theo chiều ngang:")
print(df_horizontal)
# Out:
# DataFrame xếp theo chiều ngang:
#    ser1  ser2
# 0    10   1.0
# 1     9   3.0
# 2     6  10.0
# 3     5  13.0
# 4     3   NaN
# 5     1   NaN
# 6    12   NaN
# 7     8   NaN
# 8    13   NaN

# %% [markdown]
# # 2. Xếp chồng theo chiều dọc (vertical)

# %%
df_vertical = pd.concat([ser1, ser2], axis=0).reset_index(drop=True)
print("\nSeries xếp theo chiều dọc:")
print(df_vertical)
# Out:
# Series xếp theo chiều dọc:
# 0     10
# 1      9
# 2      6
# 3      5
# 4      3
# 5      1
# 6     12
# 7      8
# 8     13
# 9      1
# 10     3
# 11    10
# 12    13
# dtype: int64

# %% [markdown]
# # 3. Lấy vị trí của các mục của ser2 trong ser1

# %%
positions = [ser1[ser1 == val].index.tolist() for val in ser2]
print("\nVị trí của các giá trị của ser2 trong ser1:")
print(positions)
# Out:
# Vị trí của các giá trị của ser2 trong ser1:
# [[5], [4], [0], [8]]
