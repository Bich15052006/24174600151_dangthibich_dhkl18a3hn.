# %%
import pandas as pd

# %% [markdown]
# # Input

# %%
ser = pd.Series(list('abcdefghijklmnopqrstuvwxyz'))
pos = [0, 4, 8, 14, 20]

# %% [markdown]
# # Trích xuất các mục tại các vị trí pos

# %%
selected_items = ser.iloc[pos]
print("Các mục được trích xuất:")
print(selected_items)
# Out:
# Các mục được trích xuất:
# 0     a
# 4     e
# 8     i
# 14    o
# 20    u
# dtype: object
